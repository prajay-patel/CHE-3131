# %% [markdown]
# # Introduction to Python (5 pts)
#
# Watch the series of introductory videos to gain some understanding of what is Python and what we are going to do be doing with it for lab.

# %%
# @title Overview
# %%html
<style>
div.alert {
    color: #0056b3;
    background-color: #d9edf7;
    border-left: 5px solid #31708f;
    padding: 0.5em;
    font-size: 1.25em;
    line-height: 1.5;
}
div.alert ul {
    margin: 0.5em 0;
}
div.alert li {
    margin-bottom: 0.5em;
}
</style>

<div class="alert alert-block alert-info">
    <strong>Questions:</strong>
    <ul>
        <li>What is the Python programming language, and what is it used for?</li>
        <li>What are the advantages and disadvantages of using Python?</li>
        <li>What is a Jupyter notebook?</li>
    </ul>

    <strong>Objectives:</strong>
    <ul>
        <li>Describe the Python programming language and its uses.</li>
        <li>Learn the basics of the Jupyter notebook.</li>
    </ul>
</div>
# Out:
# <style>
# div.alert {
#     color: #0056b3;
#     background-color: #d9edf7;
#     border-left: 5px solid #31708f;
#     padding: 0.5em;
#     font-size: 1.25em;
#     line-height: 1.5;
# }
# div.alert ul {
#     margin: 0.5em 0;
# }
# div.alert li {
#     margin-bottom: 0.5em;
# }
# </style>
#
# <div class="alert alert-block alert-info">
#     <strong>Questions:</strong>
#     <ul>
#         <li>What is the Python programming language, and what is it used for?</li>
#         <li>What are the advantages and disadvantages of using Python?</li>
#         <li>What is a Jupyter notebook?</li>
#     </ul>
#
#     <strong>Objectives:</strong>
#     <ul>
#         <li>Describe the Python programming language and its uses.</li>
#         <li>Learn the basics of the Jupyter notebook.</li>
#     </ul>
# </div>

# %%
#@title YouTube - Python
from IPython.display import YouTubeVideo
YouTubeVideo("Y8Tko2YC5hA",width=640,height=360)

# %%
#@title YouTube - Python Library 101
from IPython.display import YouTubeVideo
YouTubeVideo("NZ0laizc4ug",width=640,height=360)

# %%
#@title YouTube - Jupyter Notebooks
from IPython.display import YouTubeVideo
YouTubeVideo("L03BzGmLUUE",width=640,height=360)

# %%
# @title Relevant Python Libraries
# %%html
<style>
div.purple-box {
    color: #4b0082; /* Indigo for text */
    background-color: #f3e5f5; /* Light lavender background */
    border-left: 5px solid #7b1fa2; /* Medium purple border */
    padding: 0.5em;
    font-size: 1.25em; /* Matches the surrounding text size */
    line-height: 1.5; /* Ensures readability */
    font-family: Arial, sans-serif; /* Clean, modern font */
}
div.purple-box ul {
    margin: 0.5em 0; /* Space around the list */
}
div.purple-box li {
    margin-bottom: 0.5em; /* Space between list items */
}
</style>

<div class="purple-box">

<p>
<li> <code>numpy</code> (numerical analysis) </li>
<li> <code>scipy</code> (scientific numerical analysis) </li>
<li> <code>matplotlib</code> (plotting) </li>
<li> <code>pandas</code> (getting data into Python and analysis) </li>

</p>

</div>
# Out:
# <style>
# div.purple-box {
#     color: #4b0082; /* Indigo for text */
#     background-color: #f3e5f5; /* Light lavender background */
#     border-left: 5px solid #7b1fa2; /* Medium purple border */
#     padding: 0.5em;
#     font-size: 1.25em; /* Matches the surrounding text size */
#     line-height: 1.5; /* Ensures readability */
#     font-family: Arial, sans-serif; /* Clean, modern font */
# }
# div.purple-box ul {
#     margin: 0.5em 0; /* Space around the list */
# }
# div.purple-box li {
#     margin-bottom: 0.5em; /* Space between list items */
# }
# </style>
#
# <div class="purple-box">
#
# <p>
# <li> <code>numpy</code> (numerical analysis) </li>
# <li> <code>scipy</code> (scientific numerical analysis) </li>
# <li> <code>matplotlib</code> (plotting) </li>
# <li> <code>pandas</code> (getting data into Python and analysis) </li>
#
# </p>
#
# </div>

# %% [markdown]
# Programming etiquette involves importing packages you need at the top of a respective script/notebook. These packages are so commonly used that abbreviations are used throughout the community (Stack Overflow)
#
# ```python
# import numpy as np
# import scipy as sp
# import matplotlib.pyplot as plt
# import pandas as pd
# ```

# %% [markdown]
# # **Practice importing the packages here**
#
# Copy the import statements above in the coding cell below. You can use the play button or Shift+Enter to run the cell.

# %% [markdown]
# # **Questions**
# If you accidentally delete the text box, put your cursor into a cell. Then, hit the **+ Text** button in the top left menu to add a text block below the cell with your cursor.

# %%
# @title **Question 1**
# %%html
<style>
div.gold-note {
    color: #796748; /* Dark gold for text */
    background-color: #F7F0E2; /* Light cream/gold background */
    border-left: 5px solid #D8B266; /* Medium gold accent border */
    padding: 0.5em;
    font-size: 1.25em;
    line-height: 1.5;
    font-family: Arial, sans-serif;
}
div.gold-note ul {
    margin: 0.5em 0; /* Space around the list */
}
div.gold-note li {
    margin-bottom: 0.5em; /* Space between list items */
}
</style>

<div class="gold-note">
    <p> Briefly summarize the videos in one paragraph (~5 sentences or 250-300 words) </p>
</div>
# Out:
# <style>
# div.gold-note {
#     color: #796748; /* Dark gold for text */
#     background-color: #F7F0E2; /* Light cream/gold background */
#     border-left: 5px solid #D8B266; /* Medium gold accent border */
#     padding: 0.5em;
#     font-size: 1.25em;
#     line-height: 1.5;
#     font-family: Arial, sans-serif;
# }
# div.gold-note ul {
#     margin: 0.5em 0; /* Space around the list */
# }
# div.gold-note li {
#     margin-bottom: 0.5em; /* Space between list items */
# }
# </style>
#
# <div class="gold-note">
#     <p> Briefly summarize the videos in one paragraph (~5 sentences or 250-300 words) </p>
# </div>

# %%
# @title **Question 2**
# %%html
<style>
div.gold-note {
    color: #796748; /* Dark gold for text */
    background-color: #F7F0E2; /* Light cream/gold background */
    border-left: 5px solid #D8B266; /* Medium gold accent border */
    padding: 0.5em;
    font-size: 1.25em;
    line-height: 1.5;
    font-family: Arial, sans-serif;
}
div.gold-note ul {
    margin: 0.5em 0; /* Space around the list */
}
div.gold-note li {
    margin-bottom: 0.5em; /* Space between list items */
}
</style>

<div class="gold-note">
    <p> How do you think we will use the information presented in these videos in lab this semester? </p>
</div>
# Out:
# <style>
# div.gold-note {
#     color: #796748; /* Dark gold for text */
#     background-color: #F7F0E2; /* Light cream/gold background */
#     border-left: 5px solid #D8B266; /* Medium gold accent border */
#     padding: 0.5em;
#     font-size: 1.25em;
#     line-height: 1.5;
#     font-family: Arial, sans-serif;
# }
# div.gold-note ul {
#     margin: 0.5em 0; /* Space around the list */
# }
# div.gold-note li {
#     margin-bottom: 0.5em; /* Space between list items */
# }
# </style>
#
# <div class="gold-note">
#     <p> How do you think we will use the information presented in these videos in lab this semester? </p>
# </div>

# %%
# @title **Question 3**
# %%html
<style>
div.gold-note {
    color: #796748; /* Dark gold for text */
    background-color: #F7F0E2; /* Light cream/gold background */
    border-left: 5px solid #D8B266; /* Medium gold accent border */
    padding: 0.5em;
    font-size: 1.25em;
    line-height: 1.5;
    font-family: Arial, sans-serif;
}
div.gold-note ul {
    margin: 0.5em 0; /* Space around the list */
}
div.gold-note li {
    margin-bottom: 0.5em; /* Space between list items */
}
</style>

<div class="gold-note">
    <p> What questions do you have, if any, about any of the topics discussed in this assignment after watching the videos? </p>
</div>
# Out:
# <style>
# div.gold-note {
#     color: #796748; /* Dark gold for text */
#     background-color: #F7F0E2; /* Light cream/gold background */
#     border-left: 5px solid #D8B266; /* Medium gold accent border */
#     padding: 0.5em;
#     font-size: 1.25em;
#     line-height: 1.5;
#     font-family: Arial, sans-serif;
# }
# div.gold-note ul {
#     margin: 0.5em 0; /* Space around the list */
# }
# div.gold-note li {
#     margin-bottom: 0.5em; /* Space between list items */
# }
# </style>
#
# <div class="gold-note">
#     <p> What questions do you have, if any, about any of the topics discussed in this assignment after watching the videos? </p>
# </div>

# %%
# @title **Question 4**
# %%html
<style>
div.gold-note {
    color: #796748; /* Dark gold for text */
    background-color: #F7F0E2; /* Light cream/gold background */
    border-left: 5px solid #D8B266; /* Medium gold accent border */
    padding: 0.5em;
    font-size: 1.25em;
    line-height: 1.5;
    font-family: Arial, sans-serif;
}
div.gold-note ul {
    margin: 0.5em 0; /* Space around the list */
}
div.gold-note li {
    margin-bottom: 0.5em; /* Space between list items */
}
</style>

<div class="gold-note">
    <p> Do you have any further questions or comments about this material, or anything else that's going on in PChem Lab?</p>
</div>
# Out:
# <style>
# div.gold-note {
#     color: #796748; /* Dark gold for text */
#     background-color: #F7F0E2; /* Light cream/gold background */
#     border-left: 5px solid #D8B266; /* Medium gold accent border */
#     padding: 0.5em;
#     font-size: 1.25em;
#     line-height: 1.5;
#     font-family: Arial, sans-serif;
# }
# div.gold-note ul {
#     margin: 0.5em 0; /* Space around the list */
# }
# div.gold-note li {
#     margin-bottom: 0.5em; /* Space between list items */
# }
# </style>
#
# <div class="gold-note">
#     <p> Do you have any further questions or comments about this material, or anything else that's going on in PChem Lab?</p>
# </div>
